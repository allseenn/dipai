# %%
import pandas as pd

# %%
# Путь к файлам
file1 = "./data-2072-2024-04-15.csv"
file2 = "./data-2457-2024-05-03.csv"
file3 = "./data-2263-2024-07-08.csv"

# %%
# Считываем названия столбцов
with open(file1, "r", encoding="utf-8") as file:
    column_names = file.readline().strip().split(";")

# Создаем DataFrame, пропуская строку с описаниями столбцов
df1 = pd.read_csv(file1, sep=";", skiprows=2, names=column_names)
df1.columns = [col.replace('"', "") for col in df1.columns]

# %%
df1.head()
# Out:
#      ID                                           EDU_NAME  global_id  \
# 0  8236  Государственное бюджетное общеобразовательное ...  797946035
# 1  8237  Государственное казенное общеобразовательное у...  797949150
# 2  8238  Государственное казенное общеобразовательное у...  797949275
# 3  8239  Частное учреждение общеобразовательная организ...  797949425
# 4  8240  Автономная некоммерческая организация средняя ...  797949570
#
#         YEAR                           AdmArea                   District  \
# 0  2016-2017  Восточный административный округ          район Богородское
# 1  2016-2017  Восточный административный округ          район Богородское
# 2  2016-2017  Восточный административный округ              район Вешняки
# 3  2016-2017  Восточный административный округ              район Вешняки
# 4  2016-2017  Восточный административный округ  район Восточное Измайлово
#
#    PASSES_OVER_220  PASSER_UNDER_160
# 0                5                19 NaN
# 1               14                47 NaN
# 2                0                 1 NaN
# 3                0                 6 NaN
# 4                1                 5 NaN

# %%
df1['EDU_NAME'].value_counts()
# Out:
# EDU_NAME
# Государственное казенное общеобразовательное учреждение города Москвы «Специальная (коррекционная) общеобразовательная школа-интернат № 31»                                                             7
# Автономная некоммерческая организация средняя Общеобразовательная школа «Колибри»                                                                                                                       7
# Государственное бюджетное общеобразовательное учреждение города Москвы «Школа № 1324»                                                                                                                   7
# Государственное бюджетное общеобразовательное учреждение города Москвы «Школа № 1798 «Феникс»                                                                                                           7
# Частное учреждение средняя общеобразовательная школа «Славянско-англо-американская школа «Марина»                                                                                                       7
#                                                                                                                                                                                                        ..
# Государственное бюджетное общеобразовательное учреждение города Москвы школа № 825 имени В.А. Караковского                                                                                              1
# Автономная некоммерческая организация высшего образования «МОСКОВСКИЙ МЕЖДУНАРОДНЫЙ УНИВЕРСИТЕТ»                                                                                                        1
# Государственное бюджетное общеобразовательное учреждение города Москвы «Школа № 1502 Энергия»                                                                                                           1
# Государственное бюджетное профессиональное образовательное учреждение города Москвы «Московское среднее специальное спортивное училище № 4 имени А.Я. Гомельского» Департамента спорта города Москвы    1
# Автономная некоммерческая организация средняя общеобразовательная школа «Ювенес»                                                                                                                        1
# Name: count, Length: 1013, dtype: int64

# %% [markdown]
# ID	EDU_NAME	global_id	YEAR	AdmArea	District	PASSES_OVER_220	PASSER_UNDER_160
# 0	Код	Название образовательного учреждения	global_id	Учебный период, за который сдаётся ЕГЭ	Административный округ	Район	Количество обучающихся, набравших не менее 220...	Количество обучающихся, набравших больше 160 б...	NaN

# %%
df1 = df1.drop(columns=[""])

# %%
missing_values = df1.isnull().sum()
missing_values
# Out:
# ID                  0
# EDU_NAME            0
# global_id           0
# YEAR                0
# AdmArea             0
# District            0
# PASSES_OVER_220     0
# PASSER_UNDER_160    0
# dtype: int64

# %%
df2 = pd.read_csv(file2, sep=";", header=0, skiprows=[1])

df2.columns = [col.replace('"', "") for col in df2.columns]

# %%
df2.head()
# Out:
#    global_id   ID        Date                                 AdmArea  \
# 0  272399481  103  11.03.2016    Юго-Восточный административный округ
# 1  272399482  104  10.03.2016      Центральный административный округ
# 2  272399483  105  11.03.2016  Северо-Западный административный округ
# 3  272399484  106  11.03.2016  Северо-Западный административный округ
# 4  272399485  113  14.03.2016   Зеленоградский административный округ
#
#                District  Longitude_WGS84  Latitude_WGS84  \
# 0         район Марьино        37.746472       55.659195
# 1  Красносельский район        37.632260       55.762905
# 2          район Митино        37.357923       55.829820
# 3          район Щукино        37.455031       55.795514
# 4         район Крюково        37.189678       55.964282
#
#                           Location  \
# 0            улица Перерва, дом 39
# 1     Милютинский переулок, дом 12
# 2  улица Рословка, дом 6, корпус 2
# 3         Живописная улица, дом 40
# 4   город Зеленоград, корпус 2308А
#
#                                              Results  \
# 0  Содержание загрязняющих веществ в атмосферном ...
# 1  Содержание загрязняющих веществ в атмосферном ...
# 2  Содержание загрязняющих веществ в атмосферном ...
# 3  Содержание загрязняющих веществ в атмосферном ...
# 4  Содержание загрязняющих веществ в атмосферном ...
#
#                                             geoData  \
# 0  {coordinates=[37.746472, 55.659195], type=Point}
# 1   {coordinates=[37.63226, 55.762905], type=Point}
# 2   {coordinates=[37.357923, 55.82982], type=Point}
# 3  {coordinates=[37.455031, 55.795514], type=Point}
# 4  {coordinates=[37.189678, 55.964282], type=Point}
#
#                                      geodata_center  Unnamed: 11
# 0  {coordinates=[37.746472, 55.659195], type=Point}          NaN
# 1   {coordinates=[37.63226, 55.762905], type=Point}          NaN
# 2   {coordinates=[37.357923, 55.82982], type=Point}          NaN
# 3  {coordinates=[37.455031, 55.795514], type=Point}          NaN
# 4  {coordinates=[37.189678, 55.964282], type=Point}          NaN

# %%
df2 = df2.drop(columns=["Unnamed: 11"])

# %%
df2['Results'].value_counts()
# Out:
# Results
# Содержание загрязняющих веществ в атмосферном воздухе на жилой территории не превысило предельно допустимых максимальных разовых нормативов                                                                           7641
# Содержание загрязняющих веществ в атмосферном воздухе на жилой территории не превысило предельно допустимых максимальных разовых нормативов.                                                                          1688
# По отдельным веществам в атмосферном воздухе выявлены повышенные максимальные разовые концентрации загрязняющих веществ                                                                                                 93
# По отдельным веществам в атмосферном воздухе выявлены повышенные максимальные разовые концентрации загрязняющих веществ.                                                                                                76
# По отдельным веществам в атмосферном воздухе выявлены повышенные максимальные разовые концентрации загрязняющих веществ, обусловленные неблагоприятными метеорологическими условиями для рассеивания                    64
# Содержание загрязняющих веществ в атмосферном воздухе на жилой территории не превысило предельно допустимых максимально разовых нормативов.                                                                             53
# Содержание загрязняющих веществ в атмосферном воздухе на жилой территории не превысило предельно допустимых максимальных разовых нормативов\n                                                                           21
# По отдельным веществам в атмосферном воздухе выявлены превышения предельно допустимых максимальных разовых нормативов                                                                                                   18
# По отдельным веществам в атмосферном воздухе выявлены повышенные максимальные разовые концентрации загрязняющих веществ.\n                                                                                               1
# Содержание загрязняющих веществ в атмосферном воздухе не превысило предельно допустимых максимальных разовых нормативов                                                                                                  1
# содержание загрязняющих веществ в атмосферном воздухе на жилой территории не превысило предельно допустимых максимальных разовых нормативов                                                                              1
# По отдельным веществам в атмосферном воздухе выявлены повышенные максимальные разовые концентрации загрязняющих веществ\n                                                                                                1
# По отдельным веществам в атмосферном воздухе выявлены повышенные максимальные разовые концентрации загрязняющих веществ, обусловленные неблагоприятными метеорологическими условиями для рассеивания\n                   1
# Name: count, dtype: int64

# %%
df3 = pd.read_csv(file3, sep=";", header=0, skiprows=[1])

df3.columns = [col.replace('"', "") for col in df3.columns]

# %%
df3.head()
# Out:
#                                              OrgType ReorganizationStatus  \
# 0                                             прочее          действующее
# 1  организация дополнительного профессионального ...          действующее
# 2  организация дополнительного профессионального ...          действующее
# 3  организация дополнительного профессионального ...          действующее
# 4  организация дополнительного профессионального ...          действующее
#
#    IDEKIS                                           FullName  \
# 0   14500  Государственное автономное учреждение города М...
# 1   14494  Государственное автономное образовательное учр...
# 2   14506  Государственное автономное образовательное учр...
# 3   14605  Государственное бюджетное образовательное учре...
# 4   13070  Государственное автономное образовательное учр...
#
#                               ShortName  Number         INN        KPP  \
# 0                        ГАУ Медиацентр     NaN  7718924940  771801001
# 1  ГАОУ ДПО «Корпоративный университет»     NaN  7714239823  771301001
# 2                        ГАОУ ДПО МЦРПО     NaN  7707329480  772201001
# 3                         ГБОУ ДПО МЦВП     NaN  7723029678  772301001
# 4                          ГАОУ ДПО ЦПМ     NaN  7725618950  770401001
#
#             OGRN LegalOrganization  ...  \
# 0  1137746210161        автономное  ...
# 1  1027700566761        автономное  ...
# 2  1057707018192        автономное  ...
# 3  1027739293944         бюджетное  ...
# 4  1077761137222        автономное  ...
#
#                                    EducationPrograms EducationalServices  \
# 0                                                NaN         nested data
# 1  Профессиональное образование | высшее образова...         nested data
# 2  Дополнительное образование | дополнительное об...         nested data
# 3  Дополнительное образование | дополнительное об...         nested data
# 4  Дополнительное образование | дополнительное об...         nested data
#
#   LicensingAndAccreditation SupplementaryClassesAndGroups  \
# 0               nested data                   nested data
# 1               nested data                   nested data
# 2               nested data                   nested data
# 3               nested data                   nested data
# 4               nested data                   nested data
#
#   NumberofStudentsInOO TheContingentOfPreschoolersStudyingOO   global_id  \
# 0          nested data                           nested data  1139421628
# 1          nested data                           nested data  2386776971
# 2          nested data                           nested data  2645605456
# 3          nested data                           nested data  2645605458
# 4          nested data                           nested data  2654965921
#
#                                              geoData geodata_center  \
# 0  {coordinates=[[[37.704597369, 55.80046703], [3...            NaN
# 1  {coordinates=[[[[37.539544671, 55.799821354], ...            NaN
# 2  {coordinates=[[[[37.711001873, 55.762921204], ...            NaN
# 3  {coordinates=[[[[37.65201246, 55.742196123], [...            NaN
# 4  {coordinates=[[[[37.56961301, 55.671061893], [...            NaN
#
#   Unnamed: 26
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 27 columns]
